# %% [markdown]
# Prova

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#         DATA  ID PIASTRA CLASSE TIPOLOGIA  N° CFU 20-25 N° CFU 30-35  \
# 0  2021-03-16    S33 DUR      A         A           0.0            0
# 1  2021-03-16    S33 DUR      A         A           0.0            0
# 2  2021-03-16   S33 POST      A         A           0.0            0
# 3  2021-03-16   S33 POST      A         A           0.0            0
# 4  2021-03-16    S33 PRE      A         A           0.0            0
#
#    TOT CFU per PUNTO                BAR N° ANALISI      LOTTO
# 0                  0  BAR-QCO-21-016-01  GMP-P0619  TT-21-002
# 1                  0  BAR-QCO-21-024-01  GMP-P0662  TT-21-003
# 2                  0  BAR-QCO-21-016-01  GMP-P0619  TT-21-002
# 3                  0  BAR-QCO-21-024-01  GMP-P0662  TT-21-003
# 4                  0  BAR-QCO-21-016-01  GMP-P0619  TT-21-002
